# %% [markdown]
# <a href="https://colab.research.google.com/github/premkumar-epic/Blood_Cell_Detection/blob/main/BloodCell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !wget -P -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# Out:
# --2024-11-24 19:38:45--  https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt [following]
# --2024-11-24 19:38:45--  https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10n.pt
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip3 install Roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nhmwq3dX2803KVRmQ22h")
project = rf.workspace("clg-vtj9f").project("blood-cell-detection-bsbvn")
version = project.version(4)
dataset = version.download("yolov9")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to blood-cell-detection-4 in yolov9:: 100%|██████████| 2224/2224 [00:00<00:00, 6634.79it/s]

# %%
# !yolo task=detect mode=train epochs=25, batch=32 plots=True \
model="/content/-q/yolov10n.pt" \
data="/content/blood-cell-detection-4/data.yaml"
# Out:
# WARNING ⚠️ argument 'epochs=25,' does not require trailing comma ',', updating to 'epochs=25'.
# ...

# %%
from ultralytics import YOLOv10

model_path = "/content/runs/detect/train/weights/best.pt"
model = YOLOv10(model_path)
#model(source="/content/blood-cell-detection-4/test/images", conf=0.25, save=True)
model(source="/content/blood-cell-detection-4/valid/images", conf=0.25, save=True)
# Out:
# image 1/94 /content/blood-cell-detection-4/valid/images/BloodImage_00004_jpg.rf.4b9c9c5ec6517d1b521e5ff7ab44d2dc.jpg: 640x640 18 RBCs, 1 WBC, 10.1ms
# image 2/94 /content/blood-cell-detection-4/valid/images/BloodImage_00007_jpg.rf.340caf2b60950589ae339711ac4e5e6a.jpg: 640x640 19 RBCs, 1 WBC, 10.7ms
# image 3/94 /content/blood-cell-detection-4/valid/images/BloodImage_00009_jpg.rf.8cbdde28aa0cb0748a3a27ca867158e1.jpg: 640x640 24 RBCs, 1 WBC, 2 plateletss, 10.4ms
# image 4/94 /content/blood-cell-detection-4/valid/images/BloodImage_00018_jpg.rf.d236b99ba7e81c1e7da19c64d35b890c.jpg: 640x640 29 RBCs, 1 WBC, 10.2ms
# image 5/94 /content/blood-cell-detection-4/valid/images/BloodImage_00019_jpg.rf.830ff770aa3eb9d481b787dfe80f468e.jpg: 640x640 19 RBCs, 1 WBC, 2 plateletss, 9.9ms
# image 6/94 /content/blood-cell-detection-4/valid/images/BloodImage_00028_jpg.rf.3d6ac411f07229c979875474a33cb1a5.jpg: 640x640 23 RBCs, 1 WBC, 10.5ms
# ...

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

images = glob.glob("/content/runs/detect/predict2/*.jpg")

images_to_display = images[:10]
fig, axes = plt.subplots(2, 5, figsize=(20, 10))

for i, ax in enumerate(axes.flat):
    if i<len(images_to_display):
        img = mpimg.imread(images_to_display[i])
        ax.imshow(img)
        ax.axis('off')
    else:
      ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 27.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 70.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 13.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...

# %%
import gradio as gr
import cv2
import numpy as np
from collections import Counter

def predict_image(image):
  image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  result = model.predict(source=image_rgb, imgsz = 640, conf=0.25)

  annotated_img = result[0].plot()

  detections = result[0].boxes.data
  class_names = [model.names[int(cls)] for cls in detections[:, 5]]
  count = Counter(class_names)

  detection_str = ", ".join([f"{name}: {count}" for name, count in count.items()])
  annotated_img = annotated_img[:,:, ::-1]

  return annotated_img, detection_str
app = gr.Interface(
    predict_image,
    inputs = gr.Image(type="numpy", label="Upload a Image"),
    outputs = [gr.Image(type="numpy", label="Annotated Image"), gr.Textbox(label="Detection Count")],
    title = "Blood Cell Detection & Count",
    description = "Upload a image from microspe to detect the blood cell and theit count"
)
app.launch(debug=True)
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://00a55dccbfe16296bd.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://00a55dccbfe16296bd.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 0: 640x640 16 RBCs, 1 WBC, 62.6ms
# Speed: 7.4ms preprocess, 62.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 98.1ms
# ...
